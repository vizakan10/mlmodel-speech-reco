# %% [markdown]
# <a href="https://colab.research.google.com/github/vizakan10/myfirstrepo/blob/main/Copy_of_OpenAI_Whisper_from_Hugging_Face_Transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Nov  8 09:42:38 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
! pip install git+https://github.com/huggingface/transformers -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 52.6 MB/s eta 0:00:00
# ...

# %%
# !wget -O audio.mp3 https://www.moviesoundclips.net/movies1/captainamerica/bullies.mp3
# Out:
# --2024-11-08 09:57:01--  https://www.moviesoundclips.net/movies1/captainamerica/bullies.mp3
# Resolving www.moviesoundclips.net (www.moviesoundclips.net)... 198.54.115.219
# Connecting to www.moviesoundclips.net (www.moviesoundclips.net)|198.54.115.219|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39848 (39K) [audio/mpeg]
# Saving to: ‘audio.mp3’
#
# audio.mp3           100%[===================>]  38.91K   220KB/s    in 0.2s
#
# 2024-11-08 09:57:02 (220 KB/s) - ‘audio.mp3’ saved [39848/39848]

# %%
from IPython.display import Audio, display

display(Audio('audio.mp3', autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from transformers import pipeline

# %%
whisper = pipeline('automatic-speech-recognition', model = 'openai/whisper-medium', device = 0)
# Out:
# Device set to use cuda:0

# %%
text = whisper('audio.mp3')
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:509: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(

# %%
text
# Out:
# {'text': " I don't like bullies. I don't care where they're from."}
